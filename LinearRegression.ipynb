# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
file_name = "stringcontains_data_matching.csv"
df = pd.read_csv(file_name)
df
# Out:
#     str:pos  str:len  regexMatches  stringContains  ratio  regex:len str:type  \
# 0         0        5            95               4     26          6        M
# 1         3        8            96               7     14          6        M
# 2        64      132           589              19     31          6        M
# 3       546     1297          4108             148     28          6        M
# 4      6558    12392         33565            1390     24          6        M
# 5     37415   125077        576518           14226     41          6        M
# 6         0       10           141               4     37         12        M
# 7         2       21           271               7     39         12        M
# 8        69      127           575              19     31         12        M
# 9       417     1106          4095             122     33         12        M
# 10     5250     7733         12989             904     14         12        M
# ...

# %%
rng = np.random.RandomState(1)
x = 10 * rng.rand(50)
y = 2 * x - 5 + rng.randn(50)
plt.scatter(x, y);

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression(fit_intercept=True)

model.fit(x[:, np.newaxis], y)

xfit = np.linspace(0, 10, 1000)
yfit = model.predict(xfit[:, np.newaxis])

plt.scatter(x, y)
plt.plot(xfit, yfit);

# %%
print("Model slope:    ", model.coef_[0])
print("Model intercept:", model.intercept_)
# Out:
# Model slope:     2.027208810360695
# Model intercept: -4.998577085553202

# %%
rng = np.random.RandomState(1)
X = 10 * rng.rand(100, 3)
y = 0.5 + np.dot(X, [1.5, -2., 1.])

model.fit(X, y)
print(model.intercept_)
print(model.coef_)
# Out:
# 0.5000000000000127
# [ 1.5 -2.   1. ]

# %%
type(X)
# Out:
# numpy.ndarray

# %%
df.head()
# Out:
#    str:pos  str:len  regexMatches  stringContains  ratio  regex:len str:type  \
# 0        0        5            95               4     26          6        M
# 1        3        8            96               7     14          6        M
# 2       64      132           589              19     31          6        M
# 3      546     1297          4108             148     28          6        M
# 4     6558    12392         33565            1390     24          6        M
#
#    regex_index  string_index
# 0            0             0
# 1            0             1
# 2            0             2
# 3            0             3
# 4            0             4

# %%
X = df[["str:len", "regex:len", "str:pos"]].values
y = df[["stringContains"]].values
model.fit(X, y)
print(model.intercept_)
print(model.coef_)
# Out:
# [-4.99870064]
# [[ 0.11349408 -0.09297466  0.00056728]]

# %%
X = df[["str:len", "regex:len", "str:pos"]].values
y = df[["regexMatches"]].values
model.fit(X, y)
print(model.intercept_)
print(model.coef_)
# Out:
# [100.91715039]
# [[ 6.30017738e+00 -5.41567248e-03 -6.42346443e+00]]

# %%
X = df[["str:pos"]].values
y = df[["stringContains"]].values
model.fit(X, y)
print(model.intercept_)
print(model.coef_)
# Out:
# [126.62358069]
# [[0.25294003]]

# %%
X = df[["str:len"]].values
y = df[["regexMatches"]].values
model.fit(X, y)
print(model.intercept_)
print(model.coef_)
# Out:
# [-4555.87670746]
# [[3.94969385]]

# %%
X = df[["str:len"]].values
y = df[["stringContains"]].values
model.fit(X, y)
print(model.intercept_)
print(model.coef_)
# Out:
# [-35.67416087]
# [[0.11364788]]

# %%
file_name = "stringcontains_data_dismatching_rm.csv"
df = pd.read_csv(file_name)
df
# Out:
#     str:len  regexMatches  stringContains   ratio  regex:len str:type  \
# 0         0          50.0             4.0    13.0          6     N_RM
# 1         3          66.0             4.0    18.0          6     N_RM
# 2       127         547.0            19.0    29.0          6     N_RM
# 3      1292        5686.0           151.0    38.0          6     N_RM
# 4     12387       50438.0          1367.0    37.0          6     N_RM
# 5    125072      721186.0         14226.0    51.0          6     N_RM
# 6         0          49.0             4.0    13.0         12     N_RM
# 7        11         102.0             4.0    27.0         12     N_RM
# 8       117         566.0            17.0    33.0         12     N_RM
# 9      1096        4826.0           122.0    40.0         12     N_RM
# 10     7723       33830.0           881.0    38.0         12     N_RM
# 11    44819      194695.0          4945.0    39.0         12     N_RM
# ...

# %%
df["len:all"] = df["str:len"] * df["regex:len"]
df.head()
# Out:
#    str:len  regexMatches  stringContains  ratio  regex:len str:type  \
# 0        0          50.0             4.0   13.0          6     N_RM
# 1        3          66.0             4.0   18.0          6     N_RM
# 2      127         547.0            19.0   29.0          6     N_RM
# 3     1292        5686.0           151.0   38.0          6     N_RM
# 4    12387       50438.0          1367.0   37.0          6     N_RM
#
#    regex_index  string_index  len:all
# 0            0             0        0
# 1            0             1       18
# 2            0             2      762
# 3            0             3     7752
# 4            0             4    74322

# %%
X = df[["str:len","regex:len", "len:all"]].values
y = df[["regexMatches"]].values
model.fit(X, y)
print(model.intercept_)
print(model.coef_)
# Out:
# [-5312.60279379]
# [[ 5.15363894e+00  6.49222999e+00 -9.28108591e-04]]

# %%
t= model.predict(X2)
print(y2-t)
# Out:
# [[ 5.25188122e+03]
#  [ 5.23643701e+03]
#  [ 4.61307629e+03]
#  [-1.25242559e+03]
#  [-5.71542655e+04]
#  [-6.24405566e+05]
#  [ 5.18715964e+03]
#  [ 5.13059213e+03]
#  [ 4.59848695e+03]
#  [-3.31022150e+02]
#  [-3.36513805e+04]
#  [-2.20353621e+05]
#  [ 4.66938705e+03]
#  [ 4.61840752e+03]
#  [ 4.11151433e+03]
#  [-3.23776959e+03]
#  [-3.10153646e+04]
#  [-2.61775129e+05]
#  [ 3.97023346e+03]
#  [ 3.94002442e+03]
#  [ 3.74870046e+03]
#  [-4.41496147e+03]
#  [-3.75294068e+04]
#  [-4.33467672e+05]
#  [-1.18152359e+03]
#  [-1.22745420e+03]
#  [-1.53059625e+03]
#  [-8.75071523e+03]
#  [-5.08593405e+04]
#  [-5.25357607e+05]
#  [-7.97180032e+03]
#  [-8.01170751e+03]
#  [-8.44270515e+03]
#  [-1.22259066e+04]
#  [-5.44129837e+04]
#  [-3.29733829e+05]]

# %%
X = df[["str:len","regex:len", "len:all"]].values
y = df[["stringContains"]].values
model.fit(X, y)
print(model.intercept_)
print(model.coef_)
# Out:
# [-2.96914992]
# [[ 1.12993948e-01 -3.25830277e-02 -1.03152052e-06]]

# %%
file_name = "stringcontains_data_dismatching_edit.csv"
df2 = pd.read_csv(file_name)
df2["len:all"] = df["str:len"] * df["regex:len"]
df2.head()
# Out:
#    str:len  regexMatches  stringContains  ratio  regex:len str:type  \
# 0        5          82.0             4.0   22.0          6     N_ED
# 1        8          94.0             7.0   14.0          6     N_ED
# 2      132         634.0            19.0   33.0          6     N_ED
# 3     1297        5709.0           148.0   39.0          6     N_ED
# 4    12392       53775.0          1395.0   39.0          6     N_ED
#
#    regex_index  string_index  len:all
# 0            0             0        0
# 1            0             1       18
# 2            0             2      762
# 3            0             3     7752
# 4            0             4    74322

# %%
X2 = df2[["str:len","regex:len", "len:all"]].values
y2 = df[["stringContains"]].values
# model.fit(X, y)
# print(model.intercept_)
# print(model.coef_)

# %%
X = df[["str:len","regex:len", "len:all"]].values
y = df[["regexMatches"]].values
model.fit(X, y)
print(model.intercept_)
print(model.coef_)
# Out:
# [-5221.9737212]
# [[ 5.10909412e+00  7.43814041e+00 -1.00142938e-03]]
